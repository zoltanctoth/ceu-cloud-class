# %% [markdown]
# # AWS Rekognition Tutorial
#
# This notebook demonstrates AWS Rekognition image analysis capabilities including:
# - Celebrity recognition in images
# - Face detection and analysis
# - Emotion detection
# - Working with images stored in S3

# %% [markdown]
# ## Setup Environment
#
# Import required libraries and initialize the AWS Rekognition client.

# %%
# Import required libraries and set up our environment
import pprint

import boto3

print("📚 Setting up the environment...")

# Initialize pretty printer for better output formatting
pp = pprint.PrettyPrinter(indent=2)

# Create Rekognition client
rekognition = boto3.client("rekognition")

print("✅ Environment setup complete!")
print(f"🌍 Using AWS region: {rekognition.meta.region_name}")
# Out:
# 📚 Setting up the environment...
# ✅ Environment setup complete!
# 🌍 Using AWS region: eu-west-1

# %% [markdown]
# ## Analyze Image for Celebrities
#
# Use Rekognition to detect and identify celebrities in an image stored in S3.

# %%
# Analyze image for celebrity detection
print("🔍 Analyzing image for celebrities...")

S3_BUCKET = "de2-datasets"
S3_KEY = "soros.jpg"

print("\n📂 Image location:")
print(f"- Bucket: {S3_BUCKET}")
print(f"- Key: {S3_KEY}")

try:
    celebrity_response = rekognition.recognize_celebrities(
        Image={
            "S3Object": {
                "Bucket": S3_BUCKET,
                "Name": S3_KEY,
            }
        }
    )

    print("\n✅ Image analysis complete!")
    print(f"Found {len(celebrity_response['CelebrityFaces'])} celebrities:")
    for celeb in celebrity_response['CelebrityFaces']:
        print(f" * {celeb['Name']} - confidence: {celeb['MatchConfidence']:.1f}%")

    print("\n📦 Raw response from AWS:")
    pp.pprint(celebrity_response)

except Exception as e:
    print(f"❌ Error analyzing image: {str(e)}")
# Out:
# 🔍 Analyzing image for celebrities...
#
# 📂 Image location:
# - Bucket: de2-datasets
# - Key: soros.jpg
#
# ✅ Image analysis complete!
# Found 2 celebrities:
#  * George Soros - confidence: 100.0%
#  * Knut Buen - confidence: 76.7%
#
# 📦 Raw response from AWS:
# { 'CelebrityFaces': [ { 'Face': { 'BoundingBox': { 'Height': 0.1777108609676361,
#                                                    'Left': 0.40998968482017517,
#                                                    'Top': 0.17983101308345795,
#                                                    'Width': 0.08110128343105316},
#                                   'Confidence': 99.99593353271484,
#                                   'Emotions': [ { 'Confidence': 34.7158088684082,
#                                                   'Type': 'SURPRISED'},
#                                                 { 'Confidence': 28.680557250976562,
#                                                   'Type': 'CALM'},
#                                                 { 'Confidence': 19.15283203125,
#                                                   'Type': 'ANGRY'},
#                                                 { 'Confidence': 14.93115234375,
#                                                   'Type': 'CONFUSED'},
#                                                 { 'Confidence': 0.29144287109375,
#                                                   'Type': 'DISGUSTED'},
#                                                 { 'Confidence': 0.04374980926513672,
#                                                   'Type': 'FEAR'},
#                                                 { 'Confidence': 0.04049936681985855,
#                                                   'Type': 'HAPPY'},
#                                                 { 'Confidence': 0.025463104248046875,
#                                                   'Type': 'SAD'}],
#                                   'Landmarks': [ { 'Type': 'mouthLeft',
#                                                    'X': 0.4205980598926544,
#                                                    'Y': 0.30948859453201294},
#                                                  { 'Type': 'mouthRight',
#                                                    'X': 0.4392329454421997,
#                                                    'Y': 0.31173545122146606},
#                                                  { 'Type': 'nose',
#                                                    'X': 0.41317564249038696,
#                                                    'Y': 0.27608415484428406},
#                                                  { 'Type': 'eyeLeft',
#                                                    'X': 0.42116186022758484,
#                                                    'Y': 0.24672088027000427},
#                                                  { 'Type': 'eyeRight',
#                                                    'X': 0.44390445947647095,
#                                                    'Y': 0.24890048801898956}],
#                                   'Pose': { 'Pitch': 0.4904085099697113,
#                                             'Roll': 0.7713883519172668,
#                                             'Yaw': -45.83692169189453},
#                                   'Quality': { 'Brightness': 81.53330993652344,
#                                                'Sharpness': 38.89601135253906},
#                                   'Smile': { 'Confidence': 99.83042907714844,
#                                              'Value': False}},
#                         'Id': '4fS3YC',
#                         'KnownGender': {'Type': 'Male'},
#                         'MatchConfidence': 99.99706268310547,
#                         'Name': 'George Soros',
#                         'Urls': [ 'www.wikidata.org/wiki/Q12908',
#                                   'www.imdb.com/name/nm2982733']},
#                       { 'Face': { 'BoundingBox': { 'Height': 0.12781944870948792,
#                                                    'Left': 0.6974729299545288,
#                                                    'Top': 0.5400999188423157,
#                                                    'Width': 0.06521560251712799},
#                                   'Confidence': 99.9599609375,
#                                   'Emotions': [ { 'Confidence': 38.46354293823242,
#                                                   'Type': 'HAPPY'},
#                                                 { 'Confidence': 17.57486915588379,
#                                                   'Type': 'CALM'},
#                                                 { 'Confidence': 0.40841102600097656,
#                                                   'Type': 'SURPRISED'},
#                                                 { 'Confidence': 0.3980000913143158,
#                                                   'Type': 'CONFUSED'},
#                                                 { 'Confidence': 0.22029876708984375,
#                                                   'Type': 'SAD'},
#                                                 { 'Confidence': 0.05316734313964844,
#                                                   'Type': 'DISGUSTED'},
#                                                 { 'Confidence': 0.005412101745605469,
#                                                   'Type': 'ANGRY'},
#                                                 { 'Confidence': 0.003063678741455078,
#                                                   'Type': 'FEAR'}],
#                                   'Landmarks': [ { 'Type': 'mouthLeft',
#                                                    'X': 0.7369915246963501,
#                                                    'Y': 0.6087284684181213},
#                                                  { 'Type': 'mouthRight',
#                                                    'X': 0.7411622405052185,
#                                                    'Y': 0.5933067798614502},
#                                                  { 'Type': 'nose',
#                                                    'X': 0.724586546421051,
#                                                    'Y': 0.5896157026290894},
#                                                  { 'Type': 'eyeLeft',
#                                                    'X': 0.7148362994194031,
#                                                    'Y': 0.5937000513076782},
#                                                  { 'Type': 'eyeRight',
#                                                    'X': 0.7199230790138245,
#                                                    'Y': 0.5746967196464539}],
#                                   'Pose': { 'Pitch': 7.246677875518799,
#                                             'Roll': -15.257165908813477,
#                                             'Yaw': -27.435253143310547},
#                                   'Quality': { 'Brightness': 52.81292724609375,
#                                                'Sharpness': 7.589449882507324},
#                                   'Smile': { 'Confidence': 73.27408599853516,
#                                              'Value': False}},
#                         'Id': '1yY7V6Z',
#                         'KnownGender': {'Type': 'Male'},
#                         'MatchConfidence': 76.69530487060547,
#                         'Name': 'Knut Buen',
#                         'Urls': [ 'www.wikidata.org/wiki/Q6423865',
#                                   'www.imdb.com/name/nm7614635']}],
#   'ResponseMetadata': { 'HTTPHeaders': { 'content-length': '4900',
#                                          'content-type': 'application/x-amz-json-1.1',
#                                          'date': 'Tue, 02 Dec 2025 10:26:34 '
#                                                  'GMT',
#                                          'x-amzn-requestid': 'f5f0f9ac-b2b0-4732-93e2-096e99c9004c'},
#                         'HTTPStatusCode': 200,
#                         'RequestId': 'f5f0f9ac-b2b0-4732-93e2-096e99c9004c',
#                         'RetryAttempts': 0},
#   'UnrecognizedFaces': [ { 'BoundingBox': { 'Height': 0.13087117671966553,
#                                             'Left': 0.9051164984703064,
#                                             'Top': 0.5007240176200867,
#                                             'Width': 0.0623253732919693},
#                            'Confidence': 99.99775695800781,
#                            'Emotions': [ { 'Confidence': 56.539066314697266,
#                                            'Type': 'CALM'},
#                                          { 'Confidence': 12.40234375,
#                                            'Type': 'ANGRY'},
#                                          { 'Confidence': 6.341552734375,
#                                            'Type': 'SAD'},
#                                          { 'Confidence': 2.5647482872009277,
#                                            'Type': 'CONFUSED'},
#                                          { 'Confidence': 0.56915283203125,
#                                            'Type': 'DISGUSTED'},
#                                          { 'Confidence': 0.04547834396362305,
#                                            'Type': 'SURPRISED'},
#                                          { 'Confidence': 0.008948644623160362,
#                                            'Type': 'HAPPY'},
#                                          { 'Confidence': 0.003933906555175781,
#                                            'Type': 'FEAR'}],
#                            'Landmarks': [ { 'Type': 'mouthLeft',
#                                             'X': 0.9157488942146301,
#                                             'Y': 0.6001438498497009},
#                                           { 'Type': 'mouthRight',
#                                             'X': 0.934827446937561,
#                                             'Y': 0.592583179473877},
#                                           { 'Type': 'nose',
#                                             'X': 0.9145236611366272,
#                                             'Y': 0.5694840550422668},
#                                           { 'Type': 'eyeLeft',
#                                             'X': 0.9126050472259521,
#                                             'Y': 0.5542267560958862},
#                                           { 'Type': 'eyeRight',
#                                             'X': 0.9356653094291687,
#                                             'Y': 0.5450391173362732}],
#                            'Pose': { 'Pitch': 18.098291397094727,
#                                      'Roll': -14.272501945495605,
#                                      'Yaw': -27.887826919555664},
#                            'Quality': { 'Brightness': 68.86137390136719,
#                                         'Sharpness': 3.3018569946289062},
#                            'Smile': { 'Confidence': 99.81380462646484,
#                                       'Value': False}},
#                          { 'BoundingBox': { 'Height': 0.09439634531736374,
#                                             'Left': 0.7727396488189697,
#                                             'Top': 0.5469667315483093,
#                                             'Width': 0.0480998158454895},
#                            'Confidence': 98.51250457763672,
#                            'Emotions': [ { 'Confidence': 34.03599166870117,
#                                            'Type': 'CALM'},
#                                          { 'Confidence': 14.29129409790039,
#                                            'Type': 'HAPPY'},
#                                          { 'Confidence': 6.1309814453125,
#                                            'Type': 'SAD'},
#                                          { 'Confidence': 1.4886856079101562,
#                                            'Type': 'SURPRISED'},
#                                          { 'Confidence': 0.441741943359375,
#                                            'Type': 'FEAR'},
#                                          { 'Confidence': 0.38738250732421875,
#                                            'Type': 'ANGRY'},
#                                          { 'Confidence': 0.3185272216796875,
#                                            'Type': 'DISGUSTED'},
#                                          { 'Confidence': 0.16228356957435608,
#                                            'Type': 'CONFUSED'}],
#                            'Landmarks': [ { 'Type': 'mouthLeft',
#                                             'X': 0.7723572254180908,
#                                             'Y': 0.6182838082313538},
#                                           { 'Type': 'mouthRight',
#                                             'X': 0.7843602895736694,
#                                             'Y': 0.6269918084144592},
#                                           { 'Type': 'nose',
#                                             'X': 0.7670935392379761,
#                                             'Y': 0.6080658435821533},
#                                           { 'Type': 'eyeLeft',
#                                             'X': 0.7751026749610901,
#                                             'Y': 0.5802971720695496},
#                                           { 'Type': 'eyeRight',
#                                             'X': 0.7895296216011047,
#                                             'Y': 0.5902912020683289}],
#                            'Pose': { 'Pitch': -42.18001174926758,
#                                      'Roll': 19.594886779785156,
#                                      'Yaw': -23.994932174682617},
#                            'Quality': { 'Brightness': 23.596960067749023,
#                                         'Sharpness': 1.0484901666641235},
#                            'Smile': { 'Confidence': 78.21220397949219,
#                                       'Value': False}}]}

# %% [markdown]
# ## Process Celebrity Information
#
# Extract and display detailed information about detected celebrities including confidence scores, reference URLs, and facial emotions.

# %%
# Process and display celebrity information
print("👥 Celebrity Information:")

try:
    if not celebrity_response["CelebrityFaces"]:
        print("No celebrities detected in the image.")
    else:
        for i, celebrity in enumerate(celebrity_response["CelebrityFaces"], 1):
            print(f"\n🌟 Celebrity {i}:")
            print(f"Name: {celebrity['Name']}")
            print(f"Confidence: {celebrity['MatchConfidence']:.2f}%")
            print("\nReference URLs:")
            for url in celebrity["Urls"]:
                print(f"- https://{url}")

            # Print face details if available
            if "Face" in celebrity:
                print("\nFace Details:")
                face = celebrity["Face"]
                emotions = face.get("Emotions", [])
                if emotions:
                    top_emotion = emotions[0]  # Emotions are returned sorted by confidence
                    print(f"- Top emotion: {top_emotion['Type']} ({top_emotion['Confidence']:.1f}%)")

            print("-" * 40)

except Exception as e:
    print(f"❌ Error processing results: {str(e)}")

print("\nℹ️  Note: Celebrity recognition accuracy may vary based on image quality and database coverage")
# Out:
# 👥 Celebrity Information:
#
# 🌟 Celebrity 1:
# Name: George Soros
# Confidence: 100.00%
#
# Reference URLs:
# - https://www.wikidata.org/wiki/Q12908
# - https://www.imdb.com/name/nm2982733
#
# Face Details:
# - Top emotion: SURPRISED (34.7%)
# ----------------------------------------
#
# 🌟 Celebrity 2:
# Name: Knut Buen
# Confidence: 76.70%
#
# Reference URLs:
# - https://www.wikidata.org/wiki/Q6423865
# - https://www.imdb.com/name/nm7614635
#
# Face Details:
# - Top emotion: HAPPY (38.5%)
# ----------------------------------------
#
# ℹ️  Note: Celebrity recognition accuracy may vary based on image quality and database coverage
